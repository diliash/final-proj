# %%
from transformers import AutoModel, AutoProcessor
from transformers import DetrImageProcessor, DetrForObjectDetection
import numpy as np
import torch
from matplotlib import pyplot as plt
import torchvision
import os
from PIL import Image

device = "mps"

# %%
detr = DetrForObjectDetection.from_pretrained("diliash/detr-2024-04-05-13-03-08").to(device)
detr_processor = DetrImageProcessor.from_pretrained("diliash/detr-2024-04-05-13-03-08")

# %%
class CocoDetection(torchvision.datasets.CocoDetection):
    def __init__(self, coco_folder, processor, train=True):
        ann_file = os.path.join(coco_folder, "coco_annotation", "MotionNet_train.json" if train else "MotionNet_valid.json")
        super(CocoDetection, self).__init__(os.path.join(coco_folder, "train/origin" if train else "valid/origin"), ann_file)
        self.processor = processor

    def __getitem__(self, idx):
        img, target = super(CocoDetection, self).__getitem__(idx)
        image_id = self.ids[idx]
        target = {'image_id': image_id, 'annotations': target}
        encoding = self.processor(images=img, annotations=target, return_tensors="pt")
        pixel_values = encoding["pixel_values"].squeeze()
        target = encoding["labels"][0]
        return pixel_values, target

# %%
val_dataset = CocoDetection(coco_folder='./partnetsim-256-fixed-viewpoints/coco', processor=detr_processor, train=False)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
special_val_dataset = CocoDetection(coco_folder='./partnetsim-1024-fixed-viewpoints/coco', processor=detr_processor, train=False)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
from torch.utils.data import DataLoader

def collate_fn(batch):
  pixel_values = [item[0] for item in batch]
  encoding = detr_processor.pad(pixel_values, return_tensors="pt")
  labels = [item[1] for item in batch]
  batch = {}
  batch['pixel_values'] = encoding['pixel_values']
  batch['pixel_mask'] = encoding['pixel_mask']
  batch['labels'] = labels
  return batch

val_dataloader = DataLoader(val_dataset, collate_fn=collate_fn, batch_size=1)

# %%
import matplotlib.pyplot as plt

PARTNETSIM_COLOR_MAP = {
    1: (0.0, 107.0, 164.0),
    2: (255.0, 128.0, 14.0),
    3: (200.0, 82.0, 0.0),
    4: (171.0, 171.0, 171.0),
}

def plot_results(pil_img, scores, labels, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    for score, label, (xmin, ymin, xmax, ymax)  in zip(scores.tolist(), labels.tolist(), boxes.tolist()):
        c = [x / 255 for x in PARTNETSIM_COLOR_MAP[label]]
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        text = f'{detr.config.id2label[label]}: {score:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
aggregated_results = {}

# %%
for pixel_values, target in val_dataset:
  pixel_values = pixel_values.unsqueeze(0).to(device)
  with torch.no_grad():
    outputs = detr(pixel_values=pixel_values, pixel_mask=None)

  image_id = target['image_id'].item()
  
  image = val_dataset.coco.loadImgs(image_id)[0]
  image = Image.open(os.path.join('./partnetsim-256-fixed-viewpoints/coco/valid/origin', image['file_name']))

  width, height = image.size
  postprocessed_outputs = detr_processor.post_process_object_detection(outputs,
                                                                  target_sizes=[(height, width)],
                                                                  threshold=0.8)
  results = postprocessed_outputs[0]
  aggregated_results[image_id] = results
  #print(image_id)

  # Uncomment to see the predicted bboxes
  #plot_results(image, results['scores'], results['labels'], results['boxes'])

# %%
aggregated_results
# Out:
# {1: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  2: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  3: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  4: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  5: {'scores': tensor([0.9933, 0.9502, 0.9799], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 65.6719,  45.2676, 215.8931, 163.9143],
#           [ 94.6078, 135.5776, 189.9000, 201.0171],
#           [ 85.1700, 105.2373, 206.4181, 180.6086]], device='mps:0')},
#  6: {'scores': tensor([0.9947, 0.9962, 0.9940], device='mps:0'),
#   'labels': tensor([2, 2, 1], device='mps:0'),
#   'boxes': tensor([[110.2425, 112.4215, 194.1554, 216.4441],
#           [ 40.6674,  86.7199, 109.0812, 183.6277],
#           [ 33.9093,  46.2647, 202.3563, 139.6040]], device='mps:0')},
#  7: {'scores': tensor([0.9697], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[145.3681, 111.7668, 224.3200, 187.6268]], device='mps:0')},
#  8: {'scores': tensor([0.9251, 0.9870], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 93.8512,  62.9774, 140.8939, 128.0269],
#           [ 97.0532, 115.6240, 139.1899, 196.5129]], device='mps:0')},
#  9: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  10: {'scores': tensor([0.9527], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[103.2697,  95.8737, 219.6205, 207.7466]], device='mps:0')},
#  11: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  12: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  13: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  14: {'scores': tensor([0.9371, 0.9261], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 78.8265, 102.8666, 256.2741, 219.0132],
#           [ 94.4490, 143.4628, 228.0955, 230.2041]], device='mps:0')},
#  15: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  16: {'scores': tensor([0.9359], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[127.0904, 109.9378, 219.4259, 181.6382]], device='mps:0')},
#  17: {'scores': tensor([0.9609, 0.9760, 0.9949, 0.9664], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 66.7506, 147.2410, 187.3467, 169.1200],
#           [ 74.8638, 168.8219, 181.5369, 189.6318],
#           [ 58.7793,  58.8862, 201.4852, 125.7748],
#           [ 68.4376, 149.3186, 187.4093, 170.9614]], device='mps:0')},
#  18: {'scores': tensor([0.9649, 0.9572], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[114.3324,  69.0562, 191.3729, 215.5511],
#           [ 51.8071,  53.4088, 117.3419, 192.3331]], device='mps:0')},
#  19: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  20: {'scores': tensor([0.9182, 0.9766], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[111.3892, 150.7799, 214.0246, 186.4570],
#           [ 38.5701, 148.0672, 108.0038, 187.1238]], device='mps:0')},
#  21: {'scores': tensor([0.9848, 0.9277, 0.9547], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 75.2760,  43.4147, 217.0988, 174.8442],
#           [112.5036, 145.7005, 196.9931, 209.1455],
#           [110.9676, 135.9732, 201.8242, 199.3788]], device='mps:0')},
#  22: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  23: {'scores': tensor([0.9989, 0.9979, 0.9649, 0.9763], device='mps:0'),
#   'labels': tensor([2, 2, 2, 2], device='mps:0'),
#   'boxes': tensor([[126.6633, 143.1400, 179.3639, 185.0017],
#           [ 75.3518, 141.1820, 127.2490, 182.8064],
#           [127.2854,  85.5861, 194.7425, 133.9739],
#           [ 63.5621,  83.4461, 128.3909, 133.4851]], device='mps:0')},
#  24: {'scores': tensor([0.9549, 0.9813, 0.9643], device='mps:0'),
#   'labels': tensor([2, 2, 1], device='mps:0'),
#   'boxes': tensor([[138.7319, 117.7325, 223.4774, 183.6091],
#           [ 33.3631, 138.2016, 120.7409, 187.0071],
#           [ 25.9746,  65.8781, 116.6588, 137.5992]], device='mps:0')},
#  25: {'scores': tensor([0.9360], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 88.5015,  87.3869, 226.2496, 211.6178]], device='mps:0')},
#  26: {'scores': tensor([0.9860], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[120.0769,  85.0326, 216.2302, 176.5793]], device='mps:0')},
#  27: {'scores': tensor([0.9424, 0.9948], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 95.0270,  89.9334, 163.4169, 134.4027],
#           [ 98.9117, 130.5141, 156.6139, 187.2841]], device='mps:0')},
#  28: {'scores': tensor([0.9810], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 57.8945, 108.6206, 201.1027, 197.2476]], device='mps:0')},
#  29: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  30: {'scores': tensor([0.9971, 0.9930], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[131.7126, 104.5088, 223.1557, 180.8551],
#           [ 29.8271, 102.1326, 125.8055, 181.3266]], device='mps:0')},
#  31: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  32: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  33: {'scores': tensor([0.9763, 0.9811], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 95.7958,  84.6129, 198.2424, 227.8599],
#           [ 18.1794,  62.5328, 102.6741, 192.9352]], device='mps:0')},
#  34: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  35: {'scores': tensor([0.9943], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 26.5239,  93.1689, 104.1314, 195.5345]], device='mps:0')},
#  36: {'scores': tensor([0.9665], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 35.4838,  70.9561, 197.6997, 154.7623]], device='mps:0')},
#  37: {'scores': tensor([0.9133], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 88.3596, 106.2274, 239.9387, 214.3575]], device='mps:0')},
#  38: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  39: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  40: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  41: {'scores': tensor([0.9947, 0.9896, 0.9933], device='mps:0'),
#   'labels': tensor([2, 2, 1], device='mps:0'),
#   'boxes': tensor([[126.1040, 126.1002, 215.5572, 181.3579],
#           [ 36.3212, 128.5592, 127.9730, 184.1425],
#           [ 27.8520,  61.4555, 228.3490, 125.8224]], device='mps:0')},
#  42: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  43: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  44: {'scores': tensor([0.9929], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 23.9864,  63.8310, 172.2544, 156.7383]], device='mps:0')},
#  45: {'scores': tensor([0.9118], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[127.5886, 156.4057, 165.1242, 168.0045]], device='mps:0')},
#  46: {'scores': tensor([0.9695], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 48.4050, 101.8190, 147.6552, 218.4291]], device='mps:0')},
#  47: {'scores': tensor([0.9139, 0.9868], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[114.7365,  88.5753, 177.8879, 183.9160],
#           [123.1579, 125.4954, 170.6785, 184.8728]], device='mps:0')},
#  48: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  49: {'scores': tensor([0.9817], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 21.7600, 129.5951, 115.3803, 212.2095]], device='mps:0')},
#  50: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  51: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  52: {'scores': tensor([0.9480], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 59.6621, 104.1263, 198.1681, 194.3097]], device='mps:0')},
#  53: {'scores': tensor([0.9962, 0.9738, 0.9775], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 44.6092,  46.9577, 183.7008, 134.7862],
#           [ 50.9066,  94.3386, 175.4160, 177.9382],
#           [ 62.6590, 147.1224, 165.2942, 214.2120]], device='mps:0')},
#  54: {'scores': tensor([0.9676, 0.9412], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 60.2928,  57.1453, 197.1804, 131.5632],
#           [ 76.6017, 165.6236, 178.5509, 187.7549]], device='mps:0')},
#  55: {'scores': tensor([0.9420, 0.9911, 0.9665, 0.9453, 0.9598], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 68.4595, 147.4662, 183.8057, 175.3376],
#           [ 61.3331,  49.8366, 193.9919, 141.6258],
#           [ 77.1313, 176.8541, 177.7728, 200.1540],
#           [ 69.6161, 149.2339, 183.7899, 178.5482],
#           [ 68.2402, 142.4224, 185.6347, 171.4878]], device='mps:0')},
#  56: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  57: {'scores': tensor([0.9757, 0.9006, 0.9659], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 45.4844,  57.2947, 211.4514, 129.1143],
#           [ 68.3937, 168.3428, 189.8530, 190.0479],
#           [ 55.0633, 124.9340, 203.0482, 148.9109]], device='mps:0')},
#  58: {'scores': tensor([0.9942], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 59.2066,  93.6161, 201.1175, 190.3579]], device='mps:0')},
#  59: {'scores': tensor([0.9556], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 59.1396, 107.4460, 195.5945, 161.5693]], device='mps:0')},
#  60: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  61: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  62: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  63: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  64: {'scores': tensor([0.9777], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 87.9980,  66.4499, 183.3235, 194.3378]], device='mps:0')},
#  65: {'scores': tensor([0.9066], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 41.1023,  72.6544, 164.9081, 220.3559]], device='mps:0')},
#  66: {'scores': tensor([0.9654, 0.9714], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 55.4797, 106.8429, 114.2755, 179.9870],
#           [ 98.3039, 124.6534, 172.5629, 201.7854]], device='mps:0')},
#  67: {'scores': tensor([0.9039], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 51.7904,  85.3027, 161.1886, 218.5248]], device='mps:0')},
#  68: {'scores': tensor([0.9781], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 86.2334,  88.4355, 137.6176, 188.2745]], device='mps:0')},
#  69: {'scores': tensor([0.9908], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 43.9444, 139.7509, 212.4627, 190.9017]], device='mps:0')},
#  70: {'scores': tensor([0.9922], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 50.8478, 108.3338, 204.3325, 199.6095]], device='mps:0')},
#  71: {'scores': tensor([0.9926, 0.9589], device='mps:0'),
#   'labels': tensor([1, 2], device='mps:0'),
#   'boxes': tensor([[ 53.2143,  45.3682, 176.4706, 132.7634],
#           [ 59.2659, 108.3759, 136.4040, 210.4216]], device='mps:0')},
#  72: {'scores': tensor([0.9893, 0.9696, 0.9814, 0.9955, 0.9896], device='mps:0'),
#   'labels': tensor([2, 2, 2, 2, 2], device='mps:0'),
#   'boxes': tensor([[112.7020, 130.4019, 164.3878, 208.0794],
#           [ 73.7457, 117.8936, 117.8680, 190.6895],
#           [ 64.0478,  54.5852, 116.3614, 125.2128],
#           [ 72.7290, 113.1075, 117.8326, 189.5513],
#           [113.9380,  69.2777, 172.0132, 143.2303]], device='mps:0')},
#  73: {'scores': tensor([0.9974], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 88.9796, 101.6412, 166.0059, 181.8263]], device='mps:0')},
#  74: {'scores': tensor([0.9973, 0.9685, 0.9743, 0.9785], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 52.9963,  48.6321, 174.6848, 130.1219],
#           [ 59.5629,  95.8359, 161.8074, 158.3437],
#           [ 68.0923, 142.2166, 153.4059, 207.0538],
#           [ 63.3395, 121.4896, 156.6763, 182.6976]], device='mps:0')},
#  75: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  76: {'scores': tensor([0.9962, 0.9952], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[130.6785, 130.6071, 215.6989, 185.7809],
#           [ 36.2876, 128.4838, 127.4474, 185.8478]], device='mps:0')},
#  77: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  78: {'scores': tensor([0.9831, 0.9749, 0.9950, 0.9970], device='mps:0'),
#   'labels': tensor([2, 2, 2, 2], device='mps:0'),
#   'boxes': tensor([[137.3077, 114.9761, 187.2875, 171.8795],
#           [139.6358,  73.3577, 198.4245, 137.2540],
#           [ 84.8126,  97.7923, 147.0056, 160.4565],
#           [ 94.4477, 134.8432, 142.7996, 190.8410]], device='mps:0')},
#  79: {'scores': tensor([0.9741], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 47.0075, 125.2646, 209.7255, 157.8388]], device='mps:0')},
#  80: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  81: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  82: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  83: {'scores': tensor([0.9809, 0.9929, 0.9706], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 75.8961, 169.5562, 182.6740, 190.1317],
#           [ 55.2026,  58.0512, 201.8346, 126.6154],
#           [ 62.4344, 128.0565, 193.3044, 157.2843]], device='mps:0')},
#  84: {'scores': tensor([0.9008], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 30.6333, 102.7148, 145.9539, 207.7223]], device='mps:0')},
#  85: {'scores': tensor([0.9898, 0.9768, 0.9560, 0.9467], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 74.2515,  48.7503, 213.8478, 168.7460],
#           [ 99.0972, 142.5491, 190.8189, 202.0576],
#           [ 96.3773, 125.4453, 197.5575, 191.6445],
#           [ 93.2941, 111.6049, 204.1511, 186.8117]], device='mps:0')},
#  86: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  87: {'scores': tensor([0.9624], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[138.5038, 166.8129, 181.4489, 198.8725]], device='mps:0')},
#  88: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  89: {'scores': tensor([0.9637, 0.9062, 0.9614], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 74.4274,  48.9249, 214.8368, 167.5512],
#           [ 98.5949, 136.7099, 190.6491, 200.8478],
#           [ 92.7271, 108.3901, 204.5458, 182.9458]], device='mps:0')},
#  90: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  91: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  92: {'scores': tensor([0.9756], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 51.3434,  79.5811, 147.5663, 209.7114]], device='mps:0')},
#  93: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  94: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  95: {'scores': tensor([0.9749], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 47.0010, 154.5797, 209.8099, 193.4311]], device='mps:0')},
#  96: {'scores': tensor([0.9984, 0.9762, 0.9720], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 45.3088,  46.5409, 182.4673, 134.7516],
#           [ 60.1146, 134.2691, 166.1171, 215.9003],
#           [ 52.6305,  96.7610, 172.7267, 178.6178]], device='mps:0')},
#  97: {'scores': tensor([0.9530, 0.9399], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[120.1041, 150.4939, 152.6170, 179.4577],
#           [113.9069,  83.8354, 164.1708, 167.7729]], device='mps:0')},
#  98: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  99: {'scores': tensor([0.9917], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 45.7474, 136.6974, 210.8268, 179.0018]], device='mps:0')},
#  100: {'scores': tensor([0.9602], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 61.5448, 137.7945, 199.4101, 180.2873]], device='mps:0')},
#  101: {'scores': tensor([0.9893], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 68.3016, 112.9355, 185.7210, 199.3736]], device='mps:0')},
#  102: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  103: {'scores': tensor([0.9775, 0.9968, 0.9965], device='mps:0'),
#   'labels': tensor([2, 2, 2], device='mps:0'),
#   'boxes': tensor([[140.3108,  72.1542, 206.0423, 141.3272],
#           [ 78.1181, 100.4381, 147.2239, 171.2377],
#           [ 89.9518, 146.7866, 143.0511, 195.7404]], device='mps:0')},
#  104: {'scores': tensor([0.9864], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[110.9059, 126.7525, 208.1568, 208.5013]], device='mps:0')},
#  105: {'scores': tensor([0.9815, 0.9159], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 55.7674,  57.5050, 202.2820, 129.4519],
#           [ 73.1255, 166.0276, 184.0742, 189.8684]], device='mps:0')},
#  106: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  107: {'scores': tensor([0.9261], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 98.1039, 128.1427, 147.4079, 133.2481]], device='mps:0')},
#  108: {'scores': tensor([0.9820, 0.9945, 0.9652], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 67.8840, 165.3671, 189.6990, 188.9984],
#           [ 45.5810,  58.9190, 209.1133, 127.4044],
#           [ 53.6502, 128.8282, 199.9704, 163.6202]], device='mps:0')},
#  109: {'scores': tensor([0.9864], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 46.1067, 130.0016, 212.9500, 165.6841]], device='mps:0')},
#  110: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  111: {'scores': tensor([0.9824], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 95.5647,  97.0825, 174.1020, 164.4612]], device='mps:0')},
#  112: {'scores': tensor([0.9849], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 59.3213, 103.6577, 197.2119, 196.3843]], device='mps:0')},
#  113: {'scores': tensor([0.9341, 0.9954], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 89.4194,  62.2830, 142.4580, 134.7454],
#           [ 94.3986, 124.0147, 143.9251, 199.0470]], device='mps:0')},
#  114: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  115: {'scores': tensor([0.9116], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 56.0565, 100.1711, 195.6375, 186.9146]], device='mps:0')},
#  116: {'scores': tensor([0.9966, 0.9083, 0.9584], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 49.6455,  46.9026, 176.0544, 136.4301],
#           [ 56.3924,  92.6049, 165.4854, 176.9421],
#           [ 65.4369, 135.8211, 157.7668, 209.1394]], device='mps:0')},
#  117: {'scores': tensor([0.9829, 0.9481], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 17.1526, 109.8825, 124.5943, 195.1240],
#           [127.9510, 113.5466, 236.6689, 195.3268]], device='mps:0')},
#  118: {'scores': tensor([0.9871], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 61.0945,  89.8702, 209.1080, 202.2483]], device='mps:0')},
#  119: {'scores': tensor([0.9882], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 64.2323, 105.9723, 204.8714, 201.2748]], device='mps:0')},
#  120: {'scores': tensor([0.9528], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 48.1941, 138.2576, 206.2087, 174.2169]], device='mps:0')},
#  121: {'scores': tensor([0.9765], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 43.6812, 110.9522, 179.4538, 207.4636]], device='mps:0')},
#  122: {'scores': tensor([0.9884], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 73.2544, 141.1365, 184.2261, 191.1154]], device='mps:0')},
#  123: {'scores': tensor([0.9940], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 61.1085,  91.7607, 206.2425, 192.7451]], device='mps:0')},
#  124: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  125: {'scores': tensor([0.9793], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[140.4688, 126.3206, 200.0628, 193.8492]], device='mps:0')},
#  126: {'scores': tensor([0.9645], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[100.6828,  81.4660, 155.8701, 143.6939]], device='mps:0')},
#  127: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  128: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  129: {'scores': tensor([0.9238, 0.9800, 0.9879], device='mps:0'),
#   'labels': tensor([2, 1, 2], device='mps:0'),
#   'boxes': tensor([[146.3470,  98.3031, 214.7331, 174.5416],
#           [ 47.3212,  42.3068, 228.1697, 176.1427],
#           [ 64.8894, 138.7394, 143.5853, 207.9007]], device='mps:0')},
#  130: {'scores': tensor([0.9067, 0.9747], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[104.4456, 151.5972, 152.7833, 182.3228],
#           [ 97.0138,  83.3986, 161.3138, 135.6134]], device='mps:0')},
#  131: {'scores': tensor([0.9716, 0.9630], device='mps:0'),
#   'labels': tensor([1, 2], device='mps:0'),
#   'boxes': tensor([[ 74.0308,  49.9541, 181.4644, 142.4447],
#           [ 81.9599, 140.7433, 175.5755, 195.8767]], device='mps:0')},
#  132: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  133: {'scores': tensor([0.9926, 0.9942], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[107.5898, 114.2222, 196.5251, 213.8675],
#           [ 41.0710,  87.8721, 110.5707, 181.2366]], device='mps:0')},
#  134: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  135: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  136: {'scores': tensor([0.9007], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 70.4912,  53.9620, 182.7147, 143.4479]], device='mps:0')},
#  137: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  138: {'scores': tensor([0.9610], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 47.2386, 178.5798, 156.6877, 209.5455]], device='mps:0')},
#  139: {'scores': tensor([0.9916], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 17.4670,  61.3573, 100.3912, 193.5353]], device='mps:0')},
#  140: {'scores': tensor([0.9700], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 49.7271, 106.5753, 193.3826, 223.7896]], device='mps:0')},
#  141: {'scores': tensor([0.9976, 0.9375], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 73.2611,  81.3109, 127.9873, 177.9757],
#           [126.9802,  81.9277, 181.4178, 178.3996]], device='mps:0')},
#  142: {'scores': tensor([0.9067], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[141.0403,  75.7820, 219.3104, 179.2264]], device='mps:0')},
#  143: {'scores': tensor([0.9622, 0.9337], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[127.3696, 143.2858, 190.1352, 151.7669],
#           [130.9048, 123.8997, 198.9192, 142.0793]], device='mps:0')},
#  144: {'scores': tensor([0.9987, 0.9884, 0.9753], device='mps:0'),
#   'labels': tensor([2, 2, 2], device='mps:0'),
#   'boxes': tensor([[127.5389, 141.4725, 187.6195, 186.2010],
#           [ 73.1455, 152.2204, 129.2820, 186.2189],
#           [ 54.2274,  86.4142, 128.4396, 139.5639]], device='mps:0')},
#  145: {'scores': tensor([0.9973, 0.9165, 0.9739], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 48.0211,  47.0292, 181.4916, 131.8218],
#           [ 55.8527,  93.0814, 167.7486, 173.5049],
#           [ 62.8016, 131.7977, 162.4816, 206.7063]], device='mps:0')},
#  146: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  147: {'scores': tensor([0.9618], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 47.2788, 130.4917, 209.0908, 166.3125]], device='mps:0')},
#  148: {'scores': tensor([0.9896, 0.9765], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 98.8978, 116.3922, 143.0415, 172.8757],
#           [129.1685,  87.6720, 173.0636, 161.5318]], device='mps:0')},
#  149: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  150: {'scores': tensor([0.9516], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 40.9755, 122.2126, 217.0700, 212.0898]], device='mps:0')},
#  151: {'scores': tensor([0.9848], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 89.7991,  96.5289, 170.7267, 150.4850]], device='mps:0')},
#  152: {'scores': tensor([0.9872], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 49.1513,  99.7975, 206.2662, 199.3803]], device='mps:0')},
#  153: {'scores': tensor([0.9869], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[115.2653,  85.2988, 169.3103, 180.6795]], device='mps:0')},
#  154: {'scores': tensor([0.9049, 0.9254, 0.9245, 0.9038], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[179.6409, 125.9119, 209.0535, 148.3779],
#           [180.8852, 119.9024, 211.3359, 141.5257],
#           [ 79.2866, 166.2566, 125.5085, 194.8871],
#           [176.6459, 123.0680, 207.1203, 145.9330]], device='mps:0')},
#  155: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  156: {'scores': tensor([0.9953, 0.9259], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 50.0033,  48.1520, 162.3428, 136.4546],
#           [ 57.3627, 106.9406, 136.0688, 172.4045]], device='mps:0')},
#  157: {'scores': tensor([0.9870], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 49.6538,  75.4690, 153.3104, 209.0923]], device='mps:0')},
#  158: {'scores': tensor([0.9847], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 52.4111,  59.3127, 204.1161, 126.5608]], device='mps:0')},
#  159: {'scores': tensor([0.9900, 0.9601], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[153.6222, 126.7675, 214.1170, 161.9258],
#           [ 41.9234, 124.1980, 102.0323, 162.1136]], device='mps:0')},
#  160: {'scores': tensor([0.9911, 0.9690], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 52.0024, 115.2612, 144.2566, 204.6706],
#           [140.0611,  78.3150, 220.5452, 169.9467]], device='mps:0')},
#  161: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  162: {'scores': tensor([0.9919, 0.9277], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 86.0885,  47.4775, 212.6909, 171.2184],
#           [119.1249, 144.7882, 193.9538, 201.6074]], device='mps:0')},
#  163: {'scores': tensor([0.9525], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 19.6282, 131.2456, 237.5646, 150.9331]], device='mps:0')},
#  164: {'scores': tensor([0.9694], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 65.4053,  45.2470, 220.6249, 168.7628]], device='mps:0')},
#  165: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  166: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  167: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  168: {'scores': tensor([0.9958, 0.9622], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 93.2318,  93.9627, 140.1489, 186.2308],
#           [138.5060,  75.7630, 185.2705, 167.7275]], device='mps:0')},
#  169: {'scores': tensor([0.9983, 0.9986, 0.9695, 0.9430], device='mps:0'),
#   'labels': tensor([2, 2, 2, 2], device='mps:0'),
#   'boxes': tensor([[114.7449, 136.9986, 167.2068, 213.3606],
#           [ 69.8366, 119.2482, 118.6466, 194.0669],
#           [ 56.7416,  55.5181, 114.5133, 134.2543],
#           [112.5982,  70.6443, 178.9199, 152.2511]], device='mps:0')},
#  170: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  171: {'scores': tensor([0.9852], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 46.0461,  59.4904, 212.4164, 125.5055]], device='mps:0')},
#  172: {'scores': tensor([0.9550, 0.9908, 0.9194], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 86.1266, 113.9751, 205.1329, 191.9792],
#           [ 66.2707,  45.7838, 219.2523, 174.2760],
#           [ 90.2490, 135.0582, 196.9648, 205.4062]], device='mps:0')},
#  173: {'scores': tensor([0.9903, 0.9261, 0.9636], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 74.7900,  46.5171, 214.7725, 162.9140],
#           [101.8174, 142.7267, 190.9809, 200.6929],
#           [ 97.9833, 125.8825, 196.3677, 187.0216]], device='mps:0')},
#  174: {'scores': tensor([0.9425], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 91.7215,  93.5131, 203.6824, 209.9891]], device='mps:0')},
#  175: {'scores': tensor([0.9665, 0.9687], device='mps:0'),
#   'labels': tensor([2, 1], device='mps:0'),
#   'boxes': tensor([[ 66.6369, 145.1746, 145.0919, 212.8840],
#           [ 42.9378,  77.5638, 145.0987, 187.1143]], device='mps:0')},
#  176: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  177: {'scores': tensor([0.9942], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 64.8073, 103.5865, 204.4719, 199.7785]], device='mps:0')},
#  178: {'scores': tensor([0.9825, 0.9349, 0.9768], device='mps:0'),
#   'labels': tensor([1, 2, 2], device='mps:0'),
#   'boxes': tensor([[ 30.0348,  50.4108, 130.2872, 114.5569],
#           [111.7670,  93.9224, 194.9172, 217.3067],
#           [ 34.9303,  96.4694,  99.6672, 181.6922]], device='mps:0')},
#  179: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  180: {'scores': tensor([0.9868, 0.9629, 0.9435], device='mps:0'),
#   'labels': tensor([2, 2, 2], device='mps:0'),
#   'boxes': tensor([[116.0038, 124.4413, 157.1279, 179.8739],
#           [116.7337,  85.5221, 169.2320, 147.1131],
#           [114.6530,  85.8101, 167.7017, 179.2263]], device='mps:0')},
#  181: {'scores': tensor([0.9660], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 51.3358, 100.9744, 189.1022, 193.3808]], device='mps:0')},
#  182: {'scores': tensor([0.9742], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 49.3043, 133.2341, 208.1189, 166.7075]], device='mps:0')},
#  183: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  184: {'scores': tensor([0.9872, 0.9563, 0.9495, 0.9093], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 73.7108,  49.2501, 211.7898, 165.5789],
#           [101.1000, 141.5791, 187.1635, 199.4916],
#           [ 98.5774, 128.2296, 193.7338, 187.0314],
#           [ 96.4906, 116.6015, 198.7519, 182.7356]], device='mps:0')},
#  185: {'scores': tensor([0.9289], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 62.7250, 145.2344, 126.0610, 192.8252]], device='mps:0')},
#  186: {'scores': tensor([0.9558], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 98.2664,  58.7732, 150.1708, 190.2084]], device='mps:0')},
#  187: {'scores': tensor([0.9851, 0.9923], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[130.7754, 128.5261, 215.1880, 178.1679],
#           [ 40.4599, 129.0261, 128.2440, 178.3629]], device='mps:0')},
#  188: {'scores': tensor([0.9969], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 49.5145,  71.5598, 144.6398, 214.6779]], device='mps:0')},
#  189: {'scores': tensor([0.9672], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 69.3243,  65.5431, 205.2272, 154.9349]], device='mps:0')},
#  190: {'scores': tensor([0.9078], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 51.7922, 113.4900, 204.9653, 201.7431]], device='mps:0')},
#  191: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  192: {'scores': tensor([0.9947, 0.9951], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[127.8142, 128.2314, 217.9994, 180.3380],
#           [ 37.0152, 129.7317, 128.7337, 181.2627]], device='mps:0')},
#  193: {'scores': tensor([0.9095], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 36.2186,  64.1283, 168.5943, 223.9161]], device='mps:0')},
#  194: {'scores': tensor([0.9956, 0.9589, 0.9864], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 41.7878,  44.5994, 173.9207, 136.9678],
#           [ 50.1383,  97.4981, 149.9687, 184.8859],
#           [ 62.5456, 152.6582, 145.7746, 218.3760]], device='mps:0')},
#  195: {'scores': tensor([0.9144], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[118.2447, 127.0309, 163.6902, 181.8402]], device='mps:0')},
#  196: {'scores': tensor([0.9927], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 74.4948,  44.5506, 206.0862, 166.2539]], device='mps:0')},
#  197: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  198: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  199: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  200: {'scores': tensor([0.9581], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 54.3091, 106.0249, 193.4563, 211.3124]], device='mps:0')},
#  201: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  202: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  203: {'scores': tensor([0.9435], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 80.2758,  64.6361, 139.7545, 202.7284]], device='mps:0')},
#  204: {'scores': tensor([0.9797], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 59.6183, 104.7679, 197.3941, 190.9611]], device='mps:0')},
#  205: {'scores': tensor([0.9904, 0.9962], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[143.8074,  96.4977, 219.6554, 172.3285],
#           [ 64.0594, 131.3521, 144.6026, 205.2338]], device='mps:0')},
#  206: {'scores': tensor([0.9879], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 69.4756, 141.2315, 186.7134, 200.6577]], device='mps:0')},
#  207: {'scores': tensor([0.9936], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 89.5802,  84.3493, 224.5095, 210.4993]], device='mps:0')},
#  208: {'scores': tensor([0.9228, 0.9466, 0.9569, 0.9719], device='mps:0'),
#   'labels': tensor([1, 1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 96.2394, 139.6951, 156.1410, 143.4302],
#           [162.9996, 157.8618, 207.4733, 168.7152],
#           [161.8893, 150.8951, 209.4170, 163.2599],
#           [163.2467, 164.1303, 205.4460, 176.1930]], device='mps:0')},
#  209: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  210: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  211: {'scores': tensor([0.9938], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 94.5694,  79.9340, 168.1575, 167.8936]], device='mps:0')},
#  212: {'scores': tensor([0.9891], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[109.3630, 100.2240, 212.0188, 204.9973]], device='mps:0')},
#  213: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  214: {'scores': tensor([0.9975, 0.9143], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 43.4955,  46.4688, 182.9471, 135.1673],
#           [ 50.3682,  91.1342, 173.7112, 180.9451]], device='mps:0')},
#  215: {'scores': tensor([0.9961, 0.9723], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 20.2559, 111.9368, 127.3969, 194.4742],
#           [133.5610, 111.0360, 236.9681, 194.3049]], device='mps:0')},
#  216: {'scores': tensor([0.9437], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[138.8692, 127.6945, 188.6788, 186.2492]], device='mps:0')},
#  217: {'scores': tensor([0.9715], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[107.9586, 111.3829, 194.1420, 193.0614]], device='mps:0')},
#  218: {'scores': tensor([0.9900], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[104.1521,  79.1927, 154.7770, 173.8152]], device='mps:0')},
#  219: {'scores': tensor([0.9930], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 88.4497,  84.4870, 223.0899, 210.3736]], device='mps:0')},
#  220: {'scores': tensor([0.9748, 0.9776, 0.9883], device='mps:0'),
#   'labels': tensor([2, 1, 2], device='mps:0'),
#   'boxes': tensor([[145.1017,  98.2049, 223.5878, 174.5180],
#           [ 45.0218,  42.3309, 232.3870, 176.5830],
#           [ 64.5930, 138.7363, 147.4216, 211.7814]], device='mps:0')},
#  221: {'scores': tensor([0.9458], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 88.3839,  93.9392, 237.8775, 198.9531]], device='mps:0')},
#  222: {'scores': tensor([0.9903, 0.9361, 0.9127], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 75.5501,  43.1365, 218.0028, 173.1511],
#           [112.8422, 149.7651, 194.4404, 208.7341],
#           [111.3735, 139.3411, 199.0931, 197.9256]], device='mps:0')},
#  223: {'scores': tensor([0.9805], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 40.1777,  61.7339, 169.8810, 220.8324]], device='mps:0')},
#  224: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  225: {'scores': tensor([0.9896], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 66.2673, 105.7426, 211.2032, 208.6055]], device='mps:0')},
#  226: {'scores': tensor([0.9834, 0.9942], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[115.9988,  89.1045, 203.7360, 212.0319],
#           [ 41.1877,  67.1589, 113.3496, 183.1250]], device='mps:0')},
#  227: {'scores': tensor([0.9658], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 65.6367, 101.6885, 208.3033, 193.1265]], device='mps:0')},
#  228: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  229: {'scores': tensor([0.9717], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 41.1291,  86.1884, 108.9097, 177.2692]], device='mps:0')},
#  230: {'scores': tensor([0.9909, 0.9963], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[132.6208, 139.2028, 223.5946, 196.0150],
#           [ 33.5641, 140.9261, 129.4085, 196.4362]], device='mps:0')},
#  231: {'scores': tensor([0.9462, 0.9572], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 95.8190,  63.9470, 142.8119, 169.7741],
#           [102.3580, 159.3599, 137.6759, 195.3802]], device='mps:0')},
#  232: {'scores': tensor([0.9091], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 55.7617, 110.4328, 199.8954, 210.1136]], device='mps:0')},
#  233: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  234: {'scores': tensor([0.9751, 0.9952], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[153.5400,  83.5993, 244.9388, 183.3761],
#           [ 61.9698, 123.8938, 164.9434, 221.0718]], device='mps:0')},
#  235: {'scores': tensor([0.9517], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[128.0836,  83.1862, 215.6095, 174.3911]], device='mps:0')},
#  236: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  237: {'scores': tensor([0.9865, 0.9836, 0.9296], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[  6.2332,  71.9342, 181.6020, 164.6588],
#           [ 11.5577, 101.2916, 175.9105, 194.3925],
#           [ 19.9324, 126.5453, 173.3065, 252.1202]], device='mps:0')},
#  238: {'scores': tensor([0.9001, 0.9903], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 75.7505,  55.4580, 117.6065, 182.2237],
#           [115.7464,  64.8431, 159.3120, 197.3715]], device='mps:0')},
#  239: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  240: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  241: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  242: {'scores': tensor([0.9521, 0.9481], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[124.9477,  90.7473, 161.3693, 184.4449],
#           [ 81.4881,  75.7588, 124.1149, 174.5780]], device='mps:0')},
#  243: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  244: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  245: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  246: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  247: {'scores': tensor([0.9232, 0.9467], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 79.4460, 145.9174, 146.8017, 199.5591],
#           [116.9989,  96.6927, 209.1668, 168.5547]], device='mps:0')},
#  248: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  249: {'scores': tensor([0.9727], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[139.0188,  69.9911, 209.2946, 171.4564]], device='mps:0')},
#  250: {'scores': tensor([0.9863], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 36.9300, 111.0986,  93.3993, 179.3108]], device='mps:0')},
#  251: {'scores': tensor([0.9187, 0.9338, 0.9298], device='mps:0'),
#   'labels': tensor([2, 2, 2], device='mps:0'),
#   'boxes': tensor([[101.3461,  81.7802, 159.9332, 129.2931],
#           [100.7035,  83.2830, 158.7853, 131.6814],
#           [103.8280, 133.7650, 150.8580, 180.1230]], device='mps:0')},
#  252: {'scores': tensor([0.9854], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 45.5625, 136.1690, 211.0915, 177.9385]], device='mps:0')},
#  253: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  254: {'scores': tensor([0.9962, 0.9853], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[108.6053, 107.8527, 223.3194, 179.3708],
#           [ 37.6441, 110.5756, 113.2401, 175.4681]], device='mps:0')},
#  255: {'scores': tensor([0.9370], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 55.2956, 105.5555, 195.7791, 210.0031]], device='mps:0')},
#  256: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  257: {'scores': tensor([0.9508], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 95.1506,  92.9382, 228.2667, 212.3544]], device='mps:0')},
#  258: {'scores': tensor([0.9040, 0.9281], device='mps:0'),
#   'labels': tensor([2, 1], device='mps:0'),
#   'boxes': tensor([[ 61.7709, 121.3492, 118.8501, 174.8304],
#           [ 51.4364,  78.9306, 197.0656, 165.6697]], device='mps:0')},
#  259: {'scores': tensor([0.9971, 0.9751], device='mps:0'),
#   'labels': tensor([1, 1], device='mps:0'),
#   'boxes': tensor([[ 49.6511,  47.4560, 178.0048, 132.9957],
#           [ 55.9677,  97.6552, 165.0627, 178.2529]], device='mps:0')},
#  260: {'scores': tensor([0.9932], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 49.2529, 100.1611, 206.7727, 199.0591]], device='mps:0')},
#  261: {'scores': tensor([0.9693], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 77.5640, 168.9373, 166.5745, 213.3898]], device='mps:0')},
#  262: {'scores': tensor([0.9152], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 36.7501,  70.1478, 156.6063, 227.9824]], device='mps:0')},
#  263: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  264: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  265: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  266: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  267: {'scores': tensor([0.9975], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 91.5903,  61.9145, 140.4200, 195.8176]], device='mps:0')},
#  268: {'scores': tensor([0.9442], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 60.6153,  50.0351, 197.0333, 137.0447]], device='mps:0')},
#  269: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  270: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  271: {'scores': tensor([0.9575], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 90.3567, 100.8958, 166.2375, 170.4839]], device='mps:0')},
#  272: {'scores': tensor([0.9114], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[164.6186, 142.2083, 204.6101, 156.3252]], device='mps:0')},
#  273: {'scores': tensor([0.9855], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 39.3459,  60.0176, 171.1645, 221.1139]], device='mps:0')},
#  274: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  275: {'scores': tensor([0.9963, 0.9776, 0.9738], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 43.2922,  44.3171, 174.8430, 136.6809],
#           [ 52.0709, 100.4476, 150.6530, 183.2194],
#           [ 61.9371, 146.5715, 146.5391, 219.2402]], device='mps:0')},
#  276: {'scores': tensor([0.9976, 0.9891], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 60.7641, 135.3839, 149.7515, 208.2726],
#           [143.1629,  91.8512, 222.7214, 173.7476]], device='mps:0')},
#  277: {'scores': tensor([0.9144], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 75.2630,  92.5999, 178.1188, 169.9534]], device='mps:0')},
#  278: {'scores': tensor([0.9887], device='mps:0'),
#   'labels': tensor([1], device='mps:0'),
#   'boxes': tensor([[ 66.1140,  44.9965, 220.3623, 171.0290]], device='mps:0')},
#  279: {'scores': tensor([0.9553, 0.9954], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[148.8188,  85.7571, 244.9021, 184.0945],
#           [ 62.0536, 128.6730, 162.3103, 218.7974]], device='mps:0')},
#  280: {'scores': tensor([0.9962, 0.9914], device='mps:0'),
#   'labels': tensor([2, 2], device='mps:0'),
#   'boxes': tensor([[ 44.2083,  89.3723, 133.4921, 182.6362],
#           [127.0902,  88.1345, 211.1241, 184.6731]], device='mps:0')},
#  281: {'scores': tensor([0.9861, 0.9916, 0.9661], device='mps:0'),
#   'labels': tensor([2, 1, 2], device='mps:0'),
#   'boxes': tensor([[107.9677, 115.8848, 190.9888, 219.0320],
#           [ 30.2541,  45.7105, 202.4419, 143.0142],
#           [ 35.8208,  89.6393, 104.3719, 184.1279]], device='mps:0')},
#  282: {'scores': tensor([0.9974, 0.9873, 0.9884], device='mps:0'),
#   'labels': tensor([1, 1, 1], device='mps:0'),
#   'boxes': tensor([[ 49.5359,  47.5663, 175.8113, 131.3722],
#           [ 64.8752, 141.8350, 159.9128, 209.6919],
#           [ 55.8342,  93.1706, 166.7587, 158.6904]], device='mps:0')},
#  283: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  284: {'scores': tensor([], device='mps:0'),
#   'labels': tensor([], device='mps:0', dtype=torch.int64),
#   'boxes': tensor([], device='mps:0', size=(0, 4))},
#  285: {'scores': tensor([0.9652], device='mps:0'),
#   'labels': tensor([2], device='mps:0'),
#   'boxes': tensor([[ 62.3499,  94.7248, 205.1244, 187.9817]], device='mps:0')}}

# %% [markdown]
# Note, if you are using CUDA device for inference, you can remove .to("cpu") in the following cells. I did it since some operations are still unsupported by mps.

# %%
from transformers import AutoModel, AutoProcessor
sam_processor = AutoProcessor.from_pretrained("diliash/sam-2024-04-08-01-25-31")
sam = AutoModel.from_pretrained("diliash/sam-2024-04-08-01-25-31").to("cpu")
sam_processor.image_processor.do_normalize = False

# %%
# With 0-70 bbox augmentation
from transformers import AutoModel, AutoProcessor
sam_processor = AutoProcessor.from_pretrained("diliash/sam-2024-04-08-10-30-40")
sam = AutoModel.from_pretrained("diliash/sam-2024-04-08-10-30-40").to("cpu")
sam_processor.image_processor.do_normalize = False

# %%
# With 0-20 bbox augmentation
from transformers import AutoModel, AutoProcessor
sam_processor = AutoProcessor.from_pretrained("diliash/sam-2024-04-08-06-34-33")
sam = AutoModel.from_pretrained("diliash/sam-2024-04-08-06-34-33").to("cpu")
sam_processor.image_processor.do_normalize = False

# %%
class AggregatedResultsDataset(torch.utils.data.Dataset):
    def __init__(self, aggregated_results, coco_folder, image_mean=[0, 0, 0], image_std=[0, 0, 0]):
        self.aggregated_results = aggregated_results
        self.coco_folder = coco_folder
        self.pixel_mean = torch.tensor(image_mean)
        self.pixel_std = torch.tensor(image_std)

    def __len__(self):
        return len(self.aggregated_results)

    def __getitem__(self, idx):
        image_id = list(self.aggregated_results.keys())[idx]
        results = self.aggregated_results[image_id]

        image_info = val_dataset.coco.loadImgs(image_id)[0]
        anns = image_info
        image = Image.open(os.path.join(self.coco_folder, image_info['file_name']))

        image = image.convert("RGB")

        # Scale the bounding boxes from 256x256 to 1024x1024
        scale_factor = 1024 / 256
        bboxes = results['boxes'].cpu().numpy().tolist()
        scores = results['scores'].cpu().numpy().tolist()
        labels = results['labels'].cpu().numpy().tolist()
        scaled_bboxes = [[x * scale_factor for x in bbox] for bbox in bboxes]

        return image, scaled_bboxes, anns, scores, labels

# %%
aggregated_results_dataset = AggregatedResultsDataset(aggregated_results, coco_folder='./partnetsim-1024-fixed-viewpoints/coco/valid/origin')

# %%
def aggregated_results_collate_fn(batch):
    imgs, bboxes, anns, scores, labels = zip(*batch)

    if any(len(bbox_list) > 0 for bbox_list in bboxes):
        # Pad bboxes to have the same length within a batch
        max_bboxes = max(len(bbox_list) for bbox_list in bboxes)
        padded_bboxes = [bbox_list + [[0, 0, 0, 0]] * (max_bboxes - len(bbox_list)) for bbox_list in bboxes]
        input = sam_processor(images=list(imgs), input_boxes=padded_bboxes, return_tensors="pt").to(torch.float32).to("cpu")
        input["anns"] = anns
        input["scores"] = scores
        input["labels"] = labels
    else:
        # If there are no bounding boxes, return None
        input = None

    return input

aggregated_results_dataloader = DataLoader(aggregated_results_dataset, collate_fn=aggregated_results_collate_fn, batch_size=1)

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)

# %%
# Visualize with pred bboxes

for idx, batch in enumerate(aggregated_results_dataloader):
    if batch is None:
        # If there are no bounding boxes, show the original image without masks
        img = aggregated_results_dataset[idx][0]
        plt.figure(figsize=(10, 10))
        plt.imshow(img)
        plt.axis('off')
        plt.show()
    else:
        outputs = sam(**batch, multimask_output=False)
        raw_imgs = batch["pixel_values"].cpu().numpy()

        masks = sam_processor.post_process_masks(outputs.pred_masks, batch["original_sizes"], batch["reshaped_input_sizes"])

        for i in range(np.shape(masks)[1]):
            plt.figure(figsize=(10, 10))
            img = np.transpose(raw_imgs[0], (1, 2, 0))
            plt.imshow(img)
            show_mask(masks[0][i][0], plt.gca())
            plt.axis('off')
            plt.show()

# %%
aggreagted_masks = {}

# %%
for idx, batch in enumerate(aggregated_results_dataloader):
    if batch is not None:
        outputs = sam(**batch, multimask_output=False)
        raw_imgs = batch["pixel_values"].cpu().numpy()
        
        masks = sam_processor.post_process_masks(outputs.pred_masks, batch["original_sizes"], batch["reshaped_input_sizes"])
        aggreagted_masks[idx] = {"masks": masks, "image_info": batch["anns"], "scores": batch["scores"], "lables": batch["labels"]}

# %%
torch.save(aggreagted_masks, 'aggregated_masks_detr-0.8-sam+70.pt')
